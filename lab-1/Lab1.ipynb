# %%
import requests
import os
import json

params = {
    "api_key": SERPAPI_API_KEY,
    "engine": "youtube_video_transcript",
    "v": "3cEg2HCl50I",
    "type": "asr"
}

search = requests.get("https://serpapi.com/search", params=params)
response = search.json()

print(json.dumps(response, indent=2))
for result in response.get("transcript", []):
    snippet = result.get("snippet")
    start_time_text = result.get("start_time_text")

    print(f"SnippetL: {snippet}")
    print(f"Start Time: {start_time_text}")
    print("-" * 10)
with open('transcript.txt', 'w') as f:
    for result in response.get("transcript", []):
        snippet = result.get("snippet")
        if snippet:
            f.write(f"{snippet}\n")

print("Results saved to transcript.txt")
# Out:
# {
#   "search_metadata": {
#     "id": "698ebad34c437f6529efdc82",
#     "status": "Success",
#     "json_endpoint": "https://serpapi.com/searches/0qkCyH6EKQ0hRkEzm8RDiA/698ebad34c437f6529efdc82.json",
#     "created_at": "2026-02-13 05:46:59 UTC",
#     "processed_at": "2026-02-13 05:46:59 UTC",
#     "youtube_video_transcript_url": "https://www.youtube.com/watch?v=3cEg2HCl50I",
#     "raw_html_file": "https://serpapi.com/searches/0qkCyH6EKQ0hRkEzm8RDiA/698ebad34c437f6529efdc82.html",
#     "prettify_html_file": "https://serpapi.com/searches/0qkCyH6EKQ0hRkEzm8RDiA/698ebad34c437f6529efdc82.prettify",
#     "total_time_taken": 4.4
#   },
#   "search_parameters": {
#     "engine": "youtube_video_transcript",
#     "v": "3cEg2HCl50I",
#     "language_code": "en",
#     "type": "asr"
#   },
#   "transcript": [
#     {
#       "start_ms": 210,
#       "end_ms": 3470,
#       "snippet": "meg married amy off to Europe",
#       "start_time_text": "0:00"
#     },
#     {
# ...

# %% [markdown]
# 1. What went well?
# The instructions were clear and easy to follow.
# 2. What did not go well or what challenges you encountered?
# I copied part of the code wrong near the beginning, which caused problems later on when I was trying to retrieve the transcript for the video. I was able to figure out my error after carefully looking over the code.
