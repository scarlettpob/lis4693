# %% [markdown]
# <a href="https://colab.research.google.com/github/scarlettpob/lis4693/blob/main/lab-4/lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sklearn
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
#Task 1
import requests
import io
import pandas as pd

# Data loading and DataFrame creation (copied from previous cells to resolve NameError)
url = "https://raw.githubusercontent.com/scarlettpob/lis4693/842e856cd3c837b911596c0876559fff8a66ce46/lis4693%20/lab-4/test.csv"
response = requests.get(url)
response.raise_for_status() # Raise an exception for HTTP errors
text = response.text
df = pd.read_csv(io.StringIO(text))

X = df['Title'] + ' ' + df['Description']
y = df['Class Index']

print("Features (X) head:")
print(X.head())
print("\nTarget Labels (y) head:")
print(y.head())
# Out:
# Features (X) head:
# 0    Fears for T N pension after talks Unions repre...
# 1    The Race is On: Second Private Team Sets Launc...
# 2    Ky. Company Wins Grant to Study Peptides (AP) ...
# 3    Prediction Unit Helps Forecast Wildfires (AP) ...
# 4    Calif. Aims to Limit Farm-Related Smog (AP) AP...
# dtype: object
#
# Target Labels (y) head:
# 0    3
# 1    4
# 2    4
# 3    4
# 4    4
# Name: Class Index, dtype: int64

# %% [markdown]
# I chose to combine the 'Title' and 'Description' columns to form the feature set X. By doing this we create a more comprehensive textual representation for each data point, providing more context for the classification model.
# The 'Class Index' column was chosen as the target label y. This column explicitly contains numerical categories that represent the class or topic of each article, making it the direct variable we aim to predict in a classification task.

# %%
from sklearn.model_selection import train_test_split

# %%
#Task 2
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline

# split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Show the results of the split
print("Training set has {} samples.".format(X_train.shape[0]))
print("Testing set has {} samples.".format(X_test.shape[0]))

# Remove or replace NaN values in X_train and X_test
X_train = X_train.fillna('')  # Replace NaN with empty string
X_test = X_test.fillna('')   # Replace NaN with empty string

preprocessing = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer())
])

print("Preprocessing training data...")
train_preprocessed = preprocessing.fit_transform(X_train)

print("Preprocessing test data...")
test_preprocessed = preprocessing.transform(X_test)
# Out:
# Training set has 5320 samples.
# Testing set has 2280 samples.
# Preprocessing training data...
# Preprocessing test data...

# %%
y_test.unique()
# Out:
# array([2, 1, 4, 3])

# %%
#Task 3
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC

nb_classifier = MultinomialNB()
svm_classifier = LinearSVC()
lr_classifier = LogisticRegression(multi_class="ovr")

print("Training Naive Bayes classifier...")
nb_classifier.fit(train_preprocessed, y_train)

print("Training SVM classifier...")
svm_classifier.fit(train_preprocessed, y_train)

print("Training Logistic Regression classifier...")
lr_classifier.fit(train_preprocessed, y_train)
# Out:
# Training Naive Bayes classifier...
# Training SVM classifier...
# Training Logistic Regression classifier...
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(multi_class='ovr')

# %%
nb_predictions = nb_classifier.predict(test_preprocessed)
svm_predictions = svm_classifier.predict(test_preprocessed)
lr_predictions = lr_classifier.predict(test_preprocessed)

# %%
import numpy as np

print("NB Accuracy:", np.mean(nb_predictions == y_test))
print("SVM Accuracy:", np.mean(svm_predictions == y_test))
print("LR Accuracy:", np.mean(lr_predictions == y_test))
# Out:
# NB Accuracy: 0.8837719298245614
# SVM Accuracy: 0.8763157894736842
# LR Accuracy: 0.8692982456140351

# %%
from sklearn.metrics import classification_report

# Define target_names based on unique class indices in y_test
class_labels = sorted(y_test.unique())
target_names = [f'Class {label}' for label in class_labels]

print("NB Classification Report:")
print(classification_report(y_test, nb_predictions, target_names=target_names))

print("\nLR Classification Report:")
print(classification_report(y_test, lr_predictions, target_names=target_names))

# The 'ada_predictions' variable was not defined, so this line is removed.
# Out:
# NB Classification Report:
#               precision    recall  f1-score   support
#
#      Class 1       0.88      0.89      0.89       565
#      Class 2       0.94      0.95      0.95       576
#      Class 3       0.83      0.86      0.85       541
#      Class 4       0.88      0.83      0.85       598
#
#     accuracy                           0.88      2280
#    macro avg       0.88      0.88      0.88      2280
# weighted avg       0.88      0.88      0.88      2280
#
#
# LR Classification Report:
#               precision    recall  f1-score   support
#
#      Class 1       0.89      0.87      0.88       565
#      Class 2       0.90      0.94      0.92       576
#      Class 3       0.85      0.82      0.84       541
#      Class 4       0.84      0.84      0.84       598
#
#     accuracy                           0.87      2280
#    macro avg       0.87      0.87      0.87      2280
# weighted avg       0.87      0.87      0.87      2280

# %%
#Task 4
url = "https://github.com/scarlettpob/lis4693/blob/8860190a4d4bd23f9f2432c2c64e0b2c9be5a35c/lis4693%20/lab-4/pseudo_dataset_120_rows.csv"
response.raise_for_status() # Raise an exception for HTTP errors
raw_csv_data = response.text # Store the raw CSV string

new_data = pd.read_csv(io.StringIO(raw_csv_data))
print(new_data.head())
# Out:
#    Class Index                                              Title  \
# 0            3                  Fears for T N pension after talks
# 1            4  The Race is On: Second Private Team Sets Launc...
# 2            4      Ky. Company Wins Grant to Study Peptides (AP)
# 3            4      Prediction Unit Helps Forecast Wildfires (AP)
# 4            4        Calif. Aims to Limit Farm-Related Smog (AP)
#
#                                          Description
# 0  Unions representing workers at Turner   Newall...
# 1  SPACE.com - TORONTO, Canada -- A second\team o...
# 2  AP - A company founded by a chemistry research...
# 3  AP - It's barely dawn when Mike Fitzpatrick st...
# 4  AP - Southern California's smog-fighting agenc...

# %%
# Extract features from the new dataset
X_new = new_data['Title'] + ' ' + new_data['Description']

# Handle potential NaN values in X_new (replace with empty string)
X_new = X_new.fillna('')

# Preprocess the new features using the *same* fitted preprocessing pipeline
new_data_preprocessed = preprocessing.transform(X_new)

print(f"Shape of preprocessed new data: {new_data_preprocessed.shape}")
# Out:
# Shape of preprocessed new data: (7600, 18490)

# %%
# Make predictions on the new preprocessed data using each trained classifier
nb_new_predictions = nb_classifier.predict(new_data_preprocessed)
svm_new_predictions = svm_classifier.predict(new_data_preprocessed)
lr_new_predictions = lr_classifier.predict(new_data_preprocessed)

print("Predictions for the first 5 samples with Naive Bayes:", nb_new_predictions[:5])
print("Predictions for the first 5 samples with SVM:", svm_new_predictions[:5])
print("Predictions for the first 5 samples with Logistic Regression:", lr_new_predictions[:5])
# Out:
# Predictions for the first 5 samples with Naive Bayes: [3 4 4 4 3]
# Predictions for the first 5 samples with SVM: [3 4 4 4 4]
# Predictions for the first 5 samples with Logistic Regression: [3 4 4 2 1]

# %%
# Create a new DataFrame with the original new data and the predicted labels
predicted_df = new_data.copy()
predicted_df['NB_Predicted_Class'] = nb_new_predictions
predicted_df['SVM_Predicted_Class'] = svm_new_predictions
predicted_df['LR_Predicted_Class'] = lr_new_predictions

# Display the first few rows of the DataFrame with predictions
print("Predicted DataFrame head:")
display(predicted_df.head())

# Save the results to a CSV file
output_filename = 'predicted.csv'
predicted_df.to_csv(output_filename, index=False)

print(f"Results saved to {output_filename}")
print("You can now download 'predicted.csv' from the Colab file browser and upload it to your GitHub repository.")
# Out:
# Predicted DataFrame head:
#    Class Index                                              Title  \
# 0            3                  Fears for T N pension after talks
# 1            4  The Race is On: Second Private Team Sets Launc...
# 2            4      Ky. Company Wins Grant to Study Peptides (AP)
# 3            4      Prediction Unit Helps Forecast Wildfires (AP)
# 4            4        Calif. Aims to Limit Farm-Related Smog (AP)
#
#                                          Description  NB_Predicted_Class  \
# 0  Unions representing workers at Turner   Newall...                   3
# 1  SPACE.com - TORONTO, Canada -- A second\team o...                   4
# 2  AP - A company founded by a chemistry research...                   4
# 3  AP - It's barely dawn when Mike Fitzpatrick st...                   4
# 4  AP - Southern California's smog-fighting agenc...                   3
#
#    SVM_Predicted_Class  LR_Predicted_Class
# 0                    3                   3
# ...
